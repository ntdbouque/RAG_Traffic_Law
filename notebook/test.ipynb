# %%
import pandas as pd

# %%
import pandas as pd

# Đọc file Excel với pandas
df = pd.read_excel('/workspace/competitions/Sly/RAG_Traffic_Law/data/20_2024_TT_BQP.xlsx')

# Hiển thị dữ liệu
df.columns
# Out:
# Index(['STT', 'Ten_Dieu', 'STT_Dieu', 'Ten_Chuong', 'STT_Chuong', 'Noi_Dung',
#        'Ten_Muc', 'STT_Muc'],
#       dtype='object')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

file_path = '/workspace/competitions/Sly/RAG_Traffic_Law_experiment/data/100_2019_ND_CP.csv'
df = pd.read_csv(file_path)
df
# Out:
#     STT                                            context  \
# 0     1  Điều 1. Phạm vi điều chỉnh\n1. Nghị định này q...
# 1     2  Điều 1. Phạm vi điều chỉnh\n1. Nghị định này q...
# 2     3  Điều 1. Phạm vi điều chỉnh\n1. Nghị định này q...
# 3     4  Điều 1. Phạm vi điều chỉnh\n1. Nghị định này q...
# 4     5  Điều 5. Xử phạt người điều khiển xe ô tô và cá...
# ..  ...                                                ...
# 81   82  Điều 74. Phân định thẩm quyền xử phạt hành chí...
# 82   83  Điều 74. Phân định thẩm quyền xử phạt hành chí...
# 83   84  Điều 84. Hiệu lực thi hành\nĐiều 84. Hiệu lực ...
# 84   85  Điều 84. Hiệu lực thi hành\nĐiều 84. Hiệu lực ...
# 85   86  Điều 84. Hiệu lực thi hành\nĐiều 84. Hiệu lực ...
#
#                                                 chunk  \
# 0   1. Nghị định này quy định về hành vi vi phạm h...
# 1   1. Cá nhân, tổ chức có hành vi vi phạm hành ch...
# 2   Trong Nghị định này, các từ ngữ dưới đây được ...
# ...
