# %% [markdown]
# # Description
# - MCP tutorial from https://docs.llamaindex.ai/en/stable/examples/tools/mcp/

# %% [markdown]
# ### Using Tools from an MCP Server:

# %%
from llama_index.tools.mcp import (
    get_tools_from_mcp_url,
    aget_tools_from_mcp_url,
)

# async
tools = await aget_tools_from_mcp_url("http://127.0.0.1:8000/sse")

# %%
# or:
from llama_index.tools.mcp import BasicMCPClient

client = BasicMCPClient("http://127.0.0.1:8000/sse")

tools = await aget_tools_from_mcp_url(
    "http://127.0.0.1:8000/mcp",
    client=client,
    allowed_tools=["tool1", "tool2"],
)

# %% [markdown]
# ### Converting a Workflow to an MCP app:

# %%
from llama_index.core.workflow import (
    Context,
    Workflow,
    Event,
    StartEvent,
    StopEvent,
    step,
)
from llama_index.tools.mcp.utils import workflow_as_mcp


class RunEvent(StartEvent):
    msg: str


class InfoEvent(Event):
    msg: str


class LoudWorkflow(Workflow):
    """Useful for converting strings to uppercase and making them louder."""

    @step
    def step_one(self, ctx: Context, ev: RunEvent) -> StopEvent:
        ctx.write_event_to_stream(InfoEvent(msg="Hello, world!"))

        return StopEvent(result=ev.msg.upper() + "!")


workflow = LoudWorkflow()

mcp = workflow_as_mcp(workflow)

# %% [markdown]
# ### MCP Client Usage:

# %% [markdown]
# #### Basic Client Operations

# %%
from llama_index.tools.mcp import BasicMCPClient

# Connect to an MCP server using different transports
http_client = BasicMCPClient("https://example.com/mcp")  # Streamable HTTP
sse_client = BasicMCPClient("http://127.0.0.1:8000/sse")  # Server-Sent Events
local_client = BasicMCPClient("python", args=["server.py"])  # stdio

# List available tools
tools = await sse_client.list_tools()

# Call a tool
result = await sse_client.call_tool("calculate", {"x": 5, "y": 10})

# List available resources
resources = await sse_client.list_resources()

# Read a resource
#content, mime_type = await sse_client.read_resource("config://app")

# List available prompts
prompts = await sse_client.list_prompts()

# Get a prompt
prompt_result = await sse_client.get_prompt("greet", {"name": "World"})
# Out:
# HTTP Request: GET http://127.0.0.1:8000/sse "HTTP/1.1 200 OK"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=65304172c7004f6692c273c5a4fa81bd "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=65304172c7004f6692c273c5a4fa81bd "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=65304172c7004f6692c273c5a4fa81bd "HTTP/1.1 202 Accepted"
# HTTP Request: GET http://127.0.0.1:8000/sse "HTTP/1.1 200 OK"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=de9db2c4ffed487cb2f093962fbb6e97 "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=de9db2c4ffed487cb2f093962fbb6e97 "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=de9db2c4ffed487cb2f093962fbb6e97 "HTTP/1.1 202 Accepted"
# HTTP Request: GET http://127.0.0.1:8000/sse "HTTP/1.1 200 OK"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=50fe981affa94194bac41d871e4ffc3b "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=50fe981affa94194bac41d871e4ffc3b "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=50fe981affa94194bac41d871e4ffc3b "HTTP/1.1 202 Accepted"
# HTTP Request: GET http://127.0.0.1:8000/sse "HTTP/1.1 200 OK"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=e079d120a9394f1bb2a1136a0aaf0042 "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=e079d120a9394f1bb2a1136a0aaf0042 "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=e079d120a9394f1bb2a1136a0aaf0042 "HTTP/1.1 202 Accepted"
# HTTP Request: GET http://127.0.0.1:8000/sse "HTTP/1.1 200 OK"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=3430d4c8fd2c48e7946230d7a436d302 "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=3430d4c8fd2c48e7946230d7a436d302 "HTTP/1.1 202 Accepted"
# HTTP Request: POST http://127.0.0.1:8000/messages/?session_id=3430d4c8fd2c48e7946230d7a436d302 "HTTP/1.1 202 Accepted"
#   + Exception Group Traceback (most recent call last):
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#   |     await eval(code_obj, self.user_global_ns, self.user_ns)
#   |   File "C:\Users\duy\AppData\Local\Temp\ipykernel_22572\4168296399.py", line 24, in <module>
#   |     prompt_result = await sse_client.get_prompt("greet", {"name": "World"})
#   |                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\llama_index\tools\mcp\client.py", line 345, in get_prompt
#   |     async with self._run_session() as session:
#   |                ~~~~~~~~~~~~~~~~~^^
#   |   File "C:\Users\duy\AppData\Local\Programs\Python\Python313\Lib\contextlib.py", line 235, in __aexit__
#   |     await self.gen.athrow(value)
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\llama_index\tools\mcp\client.py", line 213, in _run_session
#   |     async with sse_client(
#   |                ~~~~~~~~~~^
#   |         self.command_or_url, auth=self.auth, headers=self.headers
#   |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |     ) as streams:
#   |     ^
#   |   File "C:\Users\duy\AppData\Local\Programs\Python\Python313\Lib\contextlib.py", line 235, in __aexit__
#   |     await self.gen.athrow(value)
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\sse.py", line 54, in sse_client
#   |     async with anyio.create_task_group() as tg:
#   |                ~~~~~~~~~~~~~~~~~~~~~~~^^
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\anyio\_backends\_asyncio.py", line 772, in __aexit__
#   |     raise BaseExceptionGroup(
#   |         "unhandled errors in a TaskGroup", self._exceptions
#   |     ) from None
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Exception Group Traceback (most recent call last):
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\sse.py", line 155, in sse_client
#     |     yield read_stream, write_stream
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\llama_index\tools\mcp\client.py", line 216, in _run_session
#     |     async with ClientSession(
#     |                ~~~~~~~~~~~~~^
#     |         *streams,
#     |         ^^^^^^^^^
#     |         read_timeout_seconds=timedelta(seconds=self.timeout),
#     |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |         sampling_callback=self.sampling_callback,
#     |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ) as session:
#     |     ^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\shared\session.py", line 223, in __aexit__
#     |     return await self._task_group.__aexit__(exc_type, exc_val, exc_tb)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\anyio\_backends\_asyncio.py", line 772, in __aexit__
#     |     raise BaseExceptionGroup(
#     |         "unhandled errors in a TaskGroup", self._exceptions
#     |     ) from None
#     | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#     +-+---------------- 1 ----------------
#       | Traceback (most recent call last):
#       |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\llama_index\tools\mcp\client.py", line 222, in _run_session
#       |     yield session
#       |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\llama_index\tools\mcp\client.py", line 346, in get_prompt
#       |     prompt = await session.get_prompt(prompt_name, arguments)
#       |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\session.py", line 320, in get_prompt
#       |     return await self.send_request(
#       |            ^^^^^^^^^^^^^^^^^^^^^^^^
#       |     ...<7 lines>...
#       |     )
#       |     ^
#       |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\shared\session.py", line 297, in send_request
#       |     raise McpError(response_or_error.error)
#       | mcp.shared.exceptions.McpError: Unknown prompt: greet
#       +------------------------------------

# %% [markdown]
# ### OAuth Authencation:

# %%
# MCP Client with Auth:
from llama_index.tools.mcp import BasicMCPClient

# Simple authentication with in-memory token storage
client = BasicMCPClient.with_oauth(
    "http://127.0.0.1:8000/sse",
    client_name="My App",
    redirect_uris=["http://localhost:9186/home"],
    # Function to handle the redirect URL (e.g., open a browser)
    redirect_handler=lambda url: print(f"Please visit: {url}"),
    # Function to get the authorization code from the user
    callback_handler=lambda: (input("Enter the code: "), None),
)

# Use the authenticated client
tools = await client.list_tools()
# Out:
# HTTP Request: GET http://127.0.0.1:8000/.well-known/oauth-authorization-server "HTTP/1.1 404 Not Found"
# HTTP Request: GET http://127.0.0.1:8000/.well-known/oauth-authorization-server "HTTP/1.1 404 Not Found"
# HTTP Request: POST http://127.0.0.1:8000/register "HTTP/1.1 404 Not Found"
# Client registration failed
# Traceback (most recent call last):
#   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\auth.py", line 291, in _get_or_register_client
#     self._client_info = await self._register_oauth_client(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.server_url, self.client_metadata, self._metadata
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\auth.py", line 200, in _register_oauth_client
#     raise httpx.HTTPStatusError(
#     ...<3 lines>...
#     )
# httpx.HTTPStatusError: Registration failed: 404
#   + Exception Group Traceback (most recent call last):
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#   |     await eval(code_obj, self.user_global_ns, self.user_ns)
#   |   File "C:\Users\duy\AppData\Local\Temp\ipykernel_22572\3900153216.py", line 16, in <module>
#   |     tools = await client.list_tools()
#   |             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\llama_index\tools\mcp\client.py", line 304, in list_tools
#   |     async with self._run_session() as session:
#   |                ~~~~~~~~~~~~~~~~~^^
#   |   File "C:\Users\duy\AppData\Local\Programs\Python\Python313\Lib\contextlib.py", line 214, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\llama_index\tools\mcp\client.py", line 213, in _run_session
#   |     async with sse_client(
#   |                ~~~~~~~~~~^
#   |         self.command_or_url, auth=self.auth, headers=self.headers
#   |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |     ) as streams:
#   |     ^
#   |   File "C:\Users\duy\AppData\Local\Programs\Python\Python313\Lib\contextlib.py", line 214, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\sse.py", line 54, in sse_client
#   |     async with anyio.create_task_group() as tg:
#   |                ~~~~~~~~~~~~~~~~~~~~~~~^^
#   |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\anyio\_backends\_asyncio.py", line 772, in __aexit__
#   |     raise BaseExceptionGroup(
#   |         "unhandled errors in a TaskGroup", self._exceptions
#   |     ) from None
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\sse.py", line 58, in sse_client
#     |     async with aconnect_sse(
#     |                ~~~~~~~~~~~~^
#     |         client,
#     |         ^^^^^^^
#     |     ...<2 lines>...
#     |         timeout=httpx.Timeout(timeout, read=sse_read_timeout),
#     |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ) as event_source:
#     |     ^
#     |   File "C:\Users\duy\AppData\Local\Programs\Python\Python313\Lib\contextlib.py", line 214, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\httpx_sse\_api.py", line 69, in aconnect_sse
#     |     async with client.stream(method, url, headers=headers, **kwargs) as response:
#     |                ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "C:\Users\duy\AppData\Local\Programs\Python\Python313\Lib\contextlib.py", line 214, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\httpx\_client.py", line 1583, in stream
#     |     response = await self.send(
#     |                ^^^^^^^^^^^^^^^^
#     |     ...<4 lines>...
#     |     )
#     |     ^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\httpx\_client.py", line 1629, in send
#     |     response = await self._send_handling_auth(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ...<4 lines>...
#     |     )
#     |     ^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\httpx\_client.py", line 1654, in _send_handling_auth
#     |     request = await auth_flow.__anext__()
#     |               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\auth.py", line 225, in async_auth_flow
#     |     await self.ensure_token()
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\auth.py", line 316, in ensure_token
#     |     await self._perform_oauth_flow()
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\auth.py", line 327, in _perform_oauth_flow
#     |     client_info = await self._get_or_register_client()
#     |                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\auth.py", line 291, in _get_or_register_client
#     |     self._client_info = await self._register_oauth_client(
#     |                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |         self.server_url, self.client_metadata, self._metadata
#     |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     )
#     |     ^
#     |   File "c:\Users\duy\Desktop\I love Claude\RAG_Traffic_Law\TruongDuy\Lib\site-packages\mcp\client\auth.py", line 200, in _register_oauth_client
#     |     raise httpx.HTTPStatusError(
#     |     ...<3 lines>...
#     |     )
#     | httpx.HTTPStatusError: Registration failed: 404
#     +------------------------------------

# %%
from llama_index.tools.mcp import BasicMCPClient
from mcp.client.auth import TokenStorage
from mcp.shared.auth import OAuthToken, OAuthClientInformationFull
from typing import Optional


class DefaultInMemoryTokenStorage(TokenStorage):
    """
    Simple in-memory token storage implementation for OAuth authentication.

    This is the default storage used when none is provided to with_oauth().
    Not suitable for production use across restarts as tokens are only stored
    in memory.
    """

    def __init__(self):
        self._tokens: Optional[OAuthToken] = None
        self._client_info: Optional[OAuthClientInformationFull] = None

    async def get_tokens(self) -> Optional[OAuthToken]:
        """Get the stored OAuth tokens."""
        return self._tokens

    async def set_tokens(self, tokens: OAuthToken) -> None:
        """Store OAuth tokens."""
        self._tokens = tokens

    async def get_client_info(self) -> Optional[OAuthClientInformationFull]:
        """Get the stored client information."""
        return self._client_info

    async def set_client_info(
        self, client_info: OAuthClientInformationFull
    ) -> None:
        """Store client information."""
        self._client_info = client_info


# Use custom storage
client = BasicMCPClient.with_oauth(
    "https://api.example.com/mcp",
    client_name="My App",
    redirect_uris=["http://localhost:3000/callback"],
    redirect_handler=lambda url: print(f"Please visit: {url}"),
    callback_handler=lambda: (input("Enter the code: "), None),
    token_storage=DefaultInMemoryTokenStorage(),
)
